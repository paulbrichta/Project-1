# %% [markdown]
# # Project 1
#
# The purpose of this notebook to prepare the DiscGolf and postcode_level_averages data for analysis.
#
# P1_data_prep:  DiscGolf.csv was sourced from https://www.kaggle.com/datasets/lanekatris/pdga-united-states-disc-golf-courses
#
# P1_data_prep:  postcode_level_averages.csv was sourced from https://www.kaggle.com/datasets/hamishgunasekara/average-income-per-zip-code-usa-2018
#
# P1_data_prep2:  Location information (reference CSV from Jason's map) was sourced from
#
# P1_data_prep2: 2010_and_2014_county_population_density.csv County population density information was sourced from https://odn.data.socrata.com/dataset/2010-and-2014-county-population-density/mmzq-86sd
#
# P1_data_prep2: median household income was saved to Unemployment.csv was sourced from https://www.ers.usda.gov/data-products/county-level-data-sets/

# %%
#Import dependencies
import pandas as pd
import numpy as np
import matplotlib as plt
import requests
import json
from config import gkey
import geopy
from geopy.geocoders import Nominatim

# # Build the endpoint URL
# baseurl = 'https://maps.googleapis.com/maps/api/geocode/json?'

# %%
#read CSV and create Pandas DataFrame
popdf = pd.DataFrame(pd.read_csv('Resources/2010_and_2014_county_population_density.csv'))
unemploymentdf = pd.DataFrame(pd.read_csv('Resources/Unemployment.csv'))

# %%
# view unemployment df format
unemploymentdf.head(2)
# Out:
#    FIPS_Code State      Area_name                  Attribute        Value
# 0          0    US  United States  Civilian_labor_force_2000  142601576.0
# 1          0    US  United States              Employed_2000  136904853.0

# %%
# create dataframe with only median household income from 2020
countyincomedf = unemploymentdf.loc[(unemploymentdf['Attribute']=='Median_Household_Income_2020')]
countyincomedf
# Out:
#         FIPS_Code State              Area_name                     Attribute  \
# 88              0    US          United States  Median_Household_Income_2020
# 177          1000    AL                Alabama  Median_Household_Income_2020
# 270          1001    AL     Autauga County, AL  Median_Household_Income_2020
# 363          1003    AL     Baldwin County, AL  Median_Household_Income_2020
# 456          1005    AL     Barbour County, AL  Median_Household_Income_2020
# ...           ...   ...                    ...                           ...
# 296295      56037    WY  Sweetwater County, WY  Median_Household_Income_2020
# 296388      56039    WY       Teton County, WY  Median_Household_Income_2020
# 296481      56041    WY       Uinta County, WY  Median_Household_Income_2020
# 296574      56043    WY    Washakie County, WY  Median_Household_Income_2020
# 296667      56045    WY      Weston County, WY  Median_Household_Income_2020
#
#           Value
# 88      67340.0
# 177     53958.0
# 270     67565.0
# 363     71135.0
# 456     38866.0
# ...         ...
# 296295  70583.0
# 296388  92488.0
# 296481  71246.0
# 296574  58532.0
# 296667  58901.0
#
# [3194 rows x 5 columns]

# %%
#split county and state info into two columns (if areaname is the state or country, Area_2 will be 'None')
countyincomedf[['Area_1','Area_2']]= countyincomedf['Area_1'].str.split(',', expand = True)
countyincomedf
# Out:
# c:\Users\chrisgru\anaconda3\envs\pythondata\lib\site-packages\pandas\core\frame.py:2963: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
#         FIPS_Code State              Area_name                     Attribute  \
# 88              0    US          United States  Median_Household_Income_2020
# 177          1000    AL                Alabama  Median_Household_Income_2020
# 270          1001    AL     Autauga County, AL  Median_Household_Income_2020
# 363          1003    AL     Baldwin County, AL  Median_Household_Income_2020
# 456          1005    AL     Barbour County, AL  Median_Household_Income_2020
# ...           ...   ...                    ...                           ...
# 296295      56037    WY  Sweetwater County, WY  Median_Household_Income_2020
# 296388      56039    WY       Teton County, WY  Median_Household_Income_2020
# 296481      56041    WY       Uinta County, WY  Median_Household_Income_2020
# 296574      56043    WY    Washakie County, WY  Median_Household_Income_2020
# 296667      56045    WY      Weston County, WY  Median_Household_Income_2020
#
#           Value             Area_1 Area_2
# 88      67340.0      United States   None
# 177     53958.0            Alabama   None
# 270     67565.0     Autauga County     AL
# 363     71135.0     Baldwin County     AL
# 456     38866.0     Barbour County     AL
# ...         ...                ...    ...
# 296295  70583.0  Sweetwater County     WY
# 296388  92488.0       Teton County     WY
# 296481  71246.0       Uinta County     WY
# 296574  58532.0    Washakie County     WY
# 296667  58901.0      Weston County     WY
#
# [3194 rows x 7 columns]

# %%
# strip leading whitespace from Area_2
countyincomedf['Area_2'] = countyincomedf['Area_2'].str.strip(' ')

# %%
#rename value column to be more descriptive (median household income)
countyincomedf = countyincomedf.rename(columns = {'Value':'MedianHHIncome'})
countyincomedf
# Out:
#         FIPS_Code State              Area_name                     Attribute  \
# 88              0    US          United States  Median_Household_Income_2020
# 177          1000    AL                Alabama  Median_Household_Income_2020
# 270          1001    AL     Autauga County, AL  Median_Household_Income_2020
# 363          1003    AL     Baldwin County, AL  Median_Household_Income_2020
# 456          1005    AL     Barbour County, AL  Median_Household_Income_2020
# ...           ...   ...                    ...                           ...
# 296295      56037    WY  Sweetwater County, WY  Median_Household_Income_2020
# 296388      56039    WY       Teton County, WY  Median_Household_Income_2020
# 296481      56041    WY       Uinta County, WY  Median_Household_Income_2020
# 296574      56043    WY    Washakie County, WY  Median_Household_Income_2020
# 296667      56045    WY      Weston County, WY  Median_Household_Income_2020
#
#         MedianHHIncome             Area_1 Area_2
# 88             67340.0      United States   None
# 177            53958.0            Alabama   None
# 270            67565.0     Autauga County     AL
# 363            71135.0     Baldwin County     AL
# 456            38866.0     Barbour County     AL
# ...                ...                ...    ...
# 296295         70583.0  Sweetwater County     WY
# 296388         92488.0       Teton County     WY
# 296481         71246.0       Uinta County     WY
# 296574         58532.0    Washakie County     WY
# 296667         58901.0      Weston County     WY
#
# [3194 rows x 7 columns]

# %%
#drop nan will remove country and state info and gaps
countyincomedf = countyincomedf.dropna()  
countyincomedf
# Out:
#         FIPS_Code State              Area_name                     Attribute  \
# 270          1001    AL     Autauga County, AL  Median_Household_Income_2020
# 363          1003    AL     Baldwin County, AL  Median_Household_Income_2020
# 456          1005    AL     Barbour County, AL  Median_Household_Income_2020
# 549          1007    AL        Bibb County, AL  Median_Household_Income_2020
# 642          1009    AL      Blount County, AL  Median_Household_Income_2020
# ...           ...   ...                    ...                           ...
# 296295      56037    WY  Sweetwater County, WY  Median_Household_Income_2020
# 296388      56039    WY       Teton County, WY  Median_Household_Income_2020
# 296481      56041    WY       Uinta County, WY  Median_Household_Income_2020
# 296574      56043    WY    Washakie County, WY  Median_Household_Income_2020
# 296667      56045    WY      Weston County, WY  Median_Household_Income_2020
#
#         MedianHHIncome             Area_1 Area_2
# 270            67565.0     Autauga County     AL
# 363            71135.0     Baldwin County     AL
# 456            38866.0     Barbour County     AL
# 549            50907.0        Bibb County     AL
# 642            55203.0      Blount County     AL
# ...                ...                ...    ...
# 296295         70583.0  Sweetwater County     WY
# 296388         92488.0       Teton County     WY
# 296481         71246.0       Uinta County     WY
# 296574         58532.0    Washakie County     WY
# 296667         58901.0      Weston County     WY
#
# [3141 rows x 7 columns]

# %%
#write data to CSV file
countyincomedf.to_csv('Resources/CountyIncome.csv')

# %%
#check df
popdf.head(2)
# Out:
#                  id                        name   type   variable  year  value
# 0  1600000US2639360     Houghton city, Michigan  place  land_area  2010  4.445
# 1  1600000US1220650  El Portal village, Florida  place  land_area  2009  0.378

# %%
#pare down dataset to include only county density data for the latest year available (2018)
countydensdf = popdf.loc[(popdf['type']=='county') & (popdf['variable']=='density')&(popdf['year']==2018)]
countydensdf
# Out:
#                     id                            name    type variable  year  \
# 859794  0500000US28151  Washington County, Mississippi  county  density  2018
# 859797  0500000US28111       Perry County, Mississippi  county  density  2018
# 859800  0500000US28019     Choctaw County, Mississippi  county  density  2018
# 859803  0500000US28057    Itawamba County, Mississippi  county  density  2018
# 859806  0500000US28015     Carroll County, Mississippi  county  density  2018
# ...                ...                             ...     ...      ...   ...
# 869199  0500000US19043            Clayton County, Iowa  county  density  2018
# 869202  0500000US19021        Buena Vista County, Iowa  county  density  2018
# 869205  0500000US19077            Guthrie County, Iowa  county  density  2018
# 869208  0500000US19091           Humboldt County, Iowa  county  density  2018
# 869211  0500000US19183         Washington County, Iowa  county  density  2018
#
#          value
# 859794  64.969
# 859797  18.583
# 859800  19.898
# 859803  44.070
# 859806  16.123
# ...        ...
# 869199  22.699
# 869202  35.240
# 869205  18.073
# 869208  22.024
# 869211  38.927
#
# [3140 rows x 6 columns]

# %%
#split name into county and state columns
countydensdf['Area_1'] = countydensdf['name']
countydensdf[['Area_1','Area_2']]= countydensdf['Area_1'].str.split(',', expand = True)
countydensdf
# Out:
# c:\Users\chrisgru\anaconda3\envs\pythondata\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# c:\Users\chrisgru\anaconda3\envs\pythondata\lib\site-packages\pandas\core\frame.py:2963: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
#                     id                            name    type variable  year  \
# 859794  0500000US28151  Washington County, Mississippi  county  density  2018
# 859797  0500000US28111       Perry County, Mississippi  county  density  2018
# 859800  0500000US28019     Choctaw County, Mississippi  county  density  2018
# 859803  0500000US28057    Itawamba County, Mississippi  county  density  2018
# 859806  0500000US28015     Carroll County, Mississippi  county  density  2018
# ...                ...                             ...     ...      ...   ...
# 869199  0500000US19043            Clayton County, Iowa  county  density  2018
# 869202  0500000US19021        Buena Vista County, Iowa  county  density  2018
# 869205  0500000US19077            Guthrie County, Iowa  county  density  2018
# 869208  0500000US19091           Humboldt County, Iowa  county  density  2018
# 869211  0500000US19183         Washington County, Iowa  county  density  2018
#
#          value              Area_1        Area_2
# 859794  64.969   Washington County   Mississippi
# 859797  18.583        Perry County   Mississippi
# 859800  19.898      Choctaw County   Mississippi
# 859803  44.070     Itawamba County   Mississippi
# 859806  16.123      Carroll County   Mississippi
# ...        ...                 ...           ...
# 869199  22.699      Clayton County          Iowa
# 869202  35.240  Buena Vista County          Iowa
# 869205  18.073      Guthrie County          Iowa
# 869208  22.024     Humboldt County          Iowa
# 869211  38.927   Washington County          Iowa
#
# [3140 rows x 8 columns]

# %%
# strip leading whitespace from Area_2
countydensdf['Area_2'] = countydensdf['Area_2'].str.strip(' ')

# %%
#rename value column to be more descriptive for population density 
countydensdf = countydensdf.rename(columns = {'value':'PopDensity'})
countydensdf
# Out:
#                     id                            name    type variable  year  \
# 859794  0500000US28151  Washington County, Mississippi  county  density  2018
# 859797  0500000US28111       Perry County, Mississippi  county  density  2018
# 859800  0500000US28019     Choctaw County, Mississippi  county  density  2018
# 859803  0500000US28057    Itawamba County, Mississippi  county  density  2018
# 859806  0500000US28015     Carroll County, Mississippi  county  density  2018
# ...                ...                             ...     ...      ...   ...
# 869199  0500000US19043            Clayton County, Iowa  county  density  2018
# 869202  0500000US19021        Buena Vista County, Iowa  county  density  2018
# 869205  0500000US19077            Guthrie County, Iowa  county  density  2018
# 869208  0500000US19091           Humboldt County, Iowa  county  density  2018
# 869211  0500000US19183         Washington County, Iowa  county  density  2018
#
#         PopDensity              Area_1        Area_2
# 859794      64.969   Washington County   Mississippi
# 859797      18.583        Perry County   Mississippi
# 859800      19.898      Choctaw County   Mississippi
# 859803      44.070     Itawamba County   Mississippi
# 859806      16.123      Carroll County   Mississippi
# ...            ...                 ...           ...
# 869199      22.699      Clayton County          Iowa
# 869202      35.240  Buena Vista County          Iowa
# 869205      18.073      Guthrie County          Iowa
# 869208      22.024     Humboldt County          Iowa
# 869211      38.927   Washington County          Iowa
#
# [3140 rows x 8 columns]

# %%
countydensdf.to_csv('Resources/CountyPopDensity.csv')

# %%
# #comment out so code isn't accidentally rerun - TAKES OVER AN HOUR TO COMPLETE CSV CREATION
# #read CSV and create Pandas DataFrame
# dgolf = pd.DataFrame(pd.read_csv('Resources/draft_dgolf_avincome.csv'))
# dgolf.head(2)
# Out:
#    Unnamed: 0                        id                      name  \
# 0           0  adventist-discovery-park  Adventist DISCovery Park
# 1           1    agape-disc-golf-course    Agape Disc Golf Course
#
#           city  state_x    zip  holeCount  rating   latitude  longitude  \
# 0     Opelika   Alabama  36804          3     NaN  32.645412 -85.378280
# 1  Scottsboro   Alabama  35769          9     NaN  34.622819 -86.080692
#
#   Modified Comments state_y  zipcode  total_pop  total_income country  \
# 0       no     none      AL    36804       8240        417346     USA
# 1       no     none      AL    35769       4170        316625     USA
#
#      avg_income
# 0  50648.786408
# 1  75929.256595

# %%
# #comment out so code isn't accidentally rerun- TAKES OVER AN HOUR TO COMPLETE CSV CREATION
# dgolfall = dgolf.copy()
# dgolfall['city'] = dgolfall['city'].str.strip(' ')
# dgolfall['cityURL'] = dgolfall['city'].str.replace(' ','%20')
# dgolfall['county'] = pd.Series(dtype = 'string')
# dgolfall['latstr'] = dgolfall['latitude'].astype(str)
# dgolfall['lonstr'] = dgolfall['longitude'].astype(str)
# dgolfall.head(2)
# Out:
#    Unnamed: 0                        id                      name        city  \
# 0           0  adventist-discovery-park  Adventist DISCovery Park     Opelika
# 1           1    agape-disc-golf-course    Agape Disc Golf Course  Scottsboro
#
#    state_x    zip  holeCount  rating   latitude  longitude  ... state_y  \
# 0  Alabama  36804          3     NaN  32.645412 -85.378280  ...      AL
# 1  Alabama  35769          9     NaN  34.622819 -86.080692  ...      AL
#
#   zipcode total_pop  total_income  country    avg_income     cityURL  county  \
# 0   36804      8240        417346      USA  50648.786408     Opelika    <NA>
# 1   35769      4170        316625      USA  75929.256595  Scottsboro    <NA>
#
#        latstr       lonstr
# 0  32.6454116  -85.3782795
# 1  34.6228192  -86.0806919
#
# [2 rows x 22 columns]

# %%
# #comment out so code isn't accidentally rerun- TAKES OVER AN HOUR TO COMPLETE CSV CREATION
# https://geopy.readthedocs.io/en/stable/
# https://www.geeksforgeeks.org/get-the-city-state-and-country-names-from-latitude-and-longitude-using-python/

# #  initialize Nominatim API
# geolocator = Nominatim(user_agent="geoapiExercises")

# for index, row in dgolfall.iterrows():
#     # get latitude, longitude from the DataFrame

#     rowlat = row['latstr']
#     rowlon = row['lonstr']
#     rowloc = geolocator.reverse(rowlat+","+rowlon)
#     rowaddress = rowloc.raw['address']
#     rowcounty = rowaddress.get('county','')
    
#     try:
#         dgolfall.loc[index, "county"] = rowcounty
#     except (KeyError, IndexError):
#         # If no county is found, set the county as no county found".
#         dgolfall.loc[index, "county"] = "No county found"

# dgolfall
# Out:
#       Unnamed: 0                                          id  \
# 0              0                    adventist-discovery-park
# 1              1                      agape-disc-golf-course
# 2              2                         aggieland-disc-golf
# 3              3                  agricultural-heritage-park
# 4              4  arab-city-park-844-shoal-creek-trail-35016
# ...          ...                                         ...
# 6765        6765                                whippin-post
# 6766        6766                  twin-oaks-disc-golf-course
# 6767        6767                           valley-park-dgc-0
# 6768        6768                    veterans-memorial-park-0
# 6769        6769     wheeling-island-marina-disc-golf-course
#
#                                          name           city        state_x  \
# 0                    Adventist DISCovery Park        Opelika        Alabama
# 1                      Agape Disc Golf Course     Scottsboro        Alabama
# 2                         Aggieland Disc Golf       Hamilton        Alabama
# 3                  Agricultural Heritage Park         Auburn        Alabama
# 4                              Arab City Park           Arab        Alabama
# ...                                       ...            ...            ...
# 6765                            Whippin' Post  Great Cacapon  West Virginia
# 6766               Twin Oaks Disc Golf Course   Crab Orchard  West Virginia
# 6767             Valley Park Disc Golf Course      Hurricane  West Virginia
# 6768                   Veterans Memorial Park     Clarksburg  West Virginia
# 6769  Wheeling Island Marina Disc Golf Course       Wheeling  West Virginia
#
#         zip  holeCount  rating   latitude  longitude  ... state_y zipcode  \
# 0     36804          3     NaN  32.645412 -85.378280  ...      AL   36804
# 1     35769          9     NaN  34.622819 -86.080692  ...      AL   35769
# 2     35570         18     NaN  34.142324 -87.988644  ...      AL   35570
# 3     36830          9     NaN  32.594459 -85.492334  ...      AL   36830
# 4     35016         18     NaN  34.317835 -86.481828  ...      AL   35016
# ...     ...        ...     ...        ...        ...  ...     ...     ...
# 6765  25422         18     4.0  39.571376 -78.403217  ...      WV   25422
# 6766  25827          9     NaN  37.740256 -81.254532  ...      WV   25827
# 6767  25526         18     NaN  38.443878 -81.994517  ...      WV   25526
# 6768  26301          9     3.0  39.272521 -80.360143  ...      WV   26301
# 6769  26003         18     1.0  40.078831 -80.736205  ...      WV   26003
#
#      total_pop  total_income  country    avg_income          cityURL  \
# 0         8240        417346      USA  50648.786408          Opelika
# 1         4170        316625      USA  75929.256595       Scottsboro
# 2         3930        174684      USA  44448.854962         Hamilton
# 3        16600       1485585      USA  89493.072289           Auburn
# 4         7210        385033      USA  53402.635229             Arab
# ...        ...           ...      ...           ...              ...
# 6765       670         34481      USA  51464.179104  Great%20Cacapon
# 6766      1210         61560      USA  50876.033058   Crab%20Orchard
# 6767      9880        712514      USA  72116.801619        Hurricane
# 6768     12350        627014      USA  50770.364372       Clarksburg
# 6769     19330       1327668      USA  68684.324884         Wheeling
#
#                county             latstr              lonstr
# 0          Lee County         32.6454116         -85.3782795
# 1      Jackson County         34.6228192         -86.0806919
# 2       Marion County         34.1423235  -87.98864379999998
# 3          Lee County         32.5944595         -85.4923344
# 4     Marshall County  34.31783529999999  -86.48182779999998
# ...               ...                ...                 ...
# 6765    Morgan County         39.5713757         -78.4032172
# 6766   Raleigh County          37.740256          -81.254532
# 6767    Putnam County         38.4438782         -81.9945167
# 6768  Harrison County         39.2725211         -80.3601434
# 6769      Ohio County         40.0788308         -80.7362053
#
# [6770 rows x 22 columns]

# %%
# #comment out so code isn't accidentally rerun- TAKES OVER AN HOUR TO COMPLETE CSV CREATION
# dgolfall = dgolfall.drop(['Unnamed: 0'],axis = 1)
# dgolfall
# Out:
#                                               id  \
# 0                       adventist-discovery-park
# 1                         agape-disc-golf-course
# 2                            aggieland-disc-golf
# 3                     agricultural-heritage-park
# 4     arab-city-park-844-shoal-creek-trail-35016
# ...                                          ...
# 6765                                whippin-post
# 6766                  twin-oaks-disc-golf-course
# 6767                           valley-park-dgc-0
# 6768                    veterans-memorial-park-0
# 6769     wheeling-island-marina-disc-golf-course
#
#                                          name           city        state_x  \
# 0                    Adventist DISCovery Park        Opelika        Alabama
# 1                      Agape Disc Golf Course     Scottsboro        Alabama
# 2                         Aggieland Disc Golf       Hamilton        Alabama
# 3                  Agricultural Heritage Park         Auburn        Alabama
# 4                              Arab City Park           Arab        Alabama
# ...                                       ...            ...            ...
# 6765                            Whippin' Post  Great Cacapon  West Virginia
# 6766               Twin Oaks Disc Golf Course   Crab Orchard  West Virginia
# 6767             Valley Park Disc Golf Course      Hurricane  West Virginia
# 6768                   Veterans Memorial Park     Clarksburg  West Virginia
# 6769  Wheeling Island Marina Disc Golf Course       Wheeling  West Virginia
#
#         zip  holeCount  rating   latitude  longitude Modified  ... state_y  \
# 0     36804          3     NaN  32.645412 -85.378280       no  ...      AL
# 1     35769          9     NaN  34.622819 -86.080692       no  ...      AL
# 2     35570         18     NaN  34.142324 -87.988644       no  ...      AL
# 3     36830          9     NaN  32.594459 -85.492334       no  ...      AL
# 4     35016         18     NaN  34.317835 -86.481828       no  ...      AL
# ...     ...        ...     ...        ...        ...      ...  ...     ...
# 6765  25422         18     4.0  39.571376 -78.403217       no  ...      WV
# 6766  25827          9     NaN  37.740256 -81.254532       no  ...      WV
# 6767  25526         18     NaN  38.443878 -81.994517       no  ...      WV
# 6768  26301          9     3.0  39.272521 -80.360143       no  ...      WV
# 6769  26003         18     1.0  40.078831 -80.736205       no  ...      WV
#
#      zipcode  total_pop  total_income  country    avg_income          cityURL  \
# 0      36804       8240        417346      USA  50648.786408          Opelika
# 1      35769       4170        316625      USA  75929.256595       Scottsboro
# 2      35570       3930        174684      USA  44448.854962         Hamilton
# 3      36830      16600       1485585      USA  89493.072289           Auburn
# 4      35016       7210        385033      USA  53402.635229             Arab
# ...      ...        ...           ...      ...           ...              ...
# 6765   25422        670         34481      USA  51464.179104  Great%20Cacapon
# 6766   25827       1210         61560      USA  50876.033058   Crab%20Orchard
# 6767   25526       9880        712514      USA  72116.801619        Hurricane
# 6768   26301      12350        627014      USA  50770.364372       Clarksburg
# 6769   26003      19330       1327668      USA  68684.324884         Wheeling
#
#                county             latstr              lonstr
# 0          Lee County         32.6454116         -85.3782795
# 1      Jackson County         34.6228192         -86.0806919
# 2       Marion County         34.1423235  -87.98864379999998
# 3          Lee County         32.5944595         -85.4923344
# 4     Marshall County  34.31783529999999  -86.48182779999998
# ...               ...                ...                 ...
# 6765    Morgan County         39.5713757         -78.4032172
# 6766   Raleigh County          37.740256          -81.254532
# 6767    Putnam County         38.4438782         -81.9945167
# 6768  Harrison County         39.2725211         -80.3601434
# 6769      Ohio County         40.0788308         -80.7362053
#
# [6770 rows x 21 columns]

# %%
#comment out so code isn't accidentally rerun- TAKES OVER AN HOUR TO COMPLETE CSV CREATION
# #export draft_dgolf_avincome to csv
dgolfall.to_csv('Resources/dgolfall.csv',index = False)

# %%
#read dgolfall.csv  need to add the index_col = 0 otherwise the dataframe ends up with an additional column "Unnamed: 0"

dgolfdf = pd.read_csv('Resources/dgolfall.csv',index_col=0)
dgolfdf.head(2)
# Out:
#                          id                      name        city  state_x  \
# 0  adventist-discovery-park  Adventist DISCovery Park     Opelika  Alabama
# 1    agape-disc-golf-course    Agape Disc Golf Course  Scottsboro  Alabama
#
#      zip  holeCount  rating   latitude  longitude Modified  ... state_y  \
# 0  36804          3     NaN  32.645412 -85.378280       no  ...      AL
# 1  35769          9     NaN  34.622819 -86.080692       no  ...      AL
#
#   zipcode  total_pop  total_income  country    avg_income     cityURL  \
# 0   36804       8240        417346      USA  50648.786408     Opelika
# 1   35769       4170        316625      USA  75929.256595  Scottsboro
#
#            county     latstr     lonstr
# 0      Lee County  32.645412 -85.378280
# 1  Jackson County  34.622819 -86.080692
#
# [2 rows x 21 columns]

# %%
dgolfdf['county_clean'] = pd.Series(dtype = 'string')
dgolfdf.head(2)
# Out:
#                          id                      name        city  state_x  \
# 0  adventist-discovery-park  Adventist DISCovery Park     Opelika  Alabama
# 1    agape-disc-golf-course    Agape Disc Golf Course  Scottsboro  Alabama
#
#      zip  holeCount  rating   latitude  longitude Modified  ... zipcode  \
# 0  36804          3     NaN  32.645412 -85.378280       no  ...   36804
# 1  35769          9     NaN  34.622819 -86.080692       no  ...   35769
#
#   total_pop  total_income  country    avg_income     cityURL          county  \
# 0      8240        417346      USA  50648.786408     Opelika      Lee County
# 1      4170        316625      USA  75929.256595  Scottsboro  Jackson County
#
#       latstr     lonstr  county_clean
# 0  32.645412 -85.378280          <NA>
# 1  34.622819 -86.080692          <NA>
#
# [2 rows x 22 columns]

# %%
#UPDATED CSV file to replace Saint with St. in the county_clean row       dgolfdf.csv
# for index, row in dgolfdf.iterrows():
#     # get latitude, longitude from the DataFrame
#     rowcounty = row['county']
#     if'Saint' not in rowcounty and "St." in rowcounty:
#         rowcounty.replace('St.','Saint')
#         row['county_clean'] = rowcounty
#     else:
#         row['county_clean'] = row['county']

# dgolfdf
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-104-ce1861b774c2> in <module>
#       2     # get latitude, longitude from the DataFrame
#       3     rowcounty = row['county']
# ----> 4     if'Saint' not in rowcounty and "St." in rowcounty:
#       5         rowcounty.replace('St.','Saint')
#       6         row['county_clean'] = rowcounty
#
# TypeError: argument of type 'float' is not iterable

# %%
# dgolfdf.to_csv('Resources/dgolfdf.csv',index = False)

# %%
dgolfdf2 = pd.read_csv('Resources/dgolfdf.csv')
dgolfdf2.head(2)
# Out:
#                          id                      name        city  state_x  \
# 0  adventist-discovery-park  Adventist DISCovery Park     Opelika  Alabama
# 1    agape-disc-golf-course    Agape Disc Golf Course  Scottsboro  Alabama
#
#      zip  holeCount  rating   latitude  longitude Modified  ... zipcode  \
# 0  36804          3     NaN  32.645412 -85.378280       no  ...   36804
# 1  35769          9     NaN  34.622819 -86.080692       no  ...   35769
#
#   total_pop  total_income  country   avg_income     cityURL          county  \
# 0      8240        417346      USA  50648.78641     Opelika      Lee County
# 1      4170        316625      USA  75929.25659  Scottsboro  Jackson County
#
#       latstr     lonstr    county_clean
# 0  32.645412 -85.378280      Lee County
# 1  34.622819 -86.080692  Jackson County
#
# [2 rows x 22 columns]

# %%
dgolfstr = dgolfdf2.copy()
# dgolfstr['state_x'] = dgolfstr['state_x'].astype(str)
# dgolfstr.dtypes
dgolfstr['county state_x'] = dgolfstr['county'] + ', '+ dgolfstr['state_x']
dgolfstr['county state_y'] = dgolfstr['county'] + ', '+ dgolfstr['state_y']
dgolfstr.head(2)
# Out:
#                          id                      name        city  state_x  \
# 0  adventist-discovery-park  Adventist DISCovery Park     Opelika  Alabama
# 1    agape-disc-golf-course    Agape Disc Golf Course  Scottsboro  Alabama
#
#      zip  holeCount  rating   latitude  longitude Modified  ... total_income  \
# 0  36804          3     NaN  32.645412 -85.378280       no  ...       417346
# 1  35769          9     NaN  34.622819 -86.080692       no  ...       316625
#
#   country   avg_income     cityURL          county     latstr     lonstr  \
# 0     USA  50648.78641     Opelika      Lee County  32.645412 -85.378280
# 1     USA  75929.25659  Scottsboro  Jackson County  34.622819 -86.080692
#
#      county_clean           county state_x      county state_y
# 0      Lee County      Lee County, Alabama      Lee County, AL
# 1  Jackson County  Jackson County, Alabama  Jackson County, AL
#
# [2 rows x 24 columns]

# %%
#merge this df using county state_x
countydensdf.head(2)
# Out:
#                     id                            name    type variable  year  \
# 859794  0500000US28151  Washington County, Mississippi  county  density  2018
# 859797  0500000US28111       Perry County, Mississippi  county  density  2018
#
#         PopDensity             Area_1       Area_2
# 859794      64.969  Washington County  Mississippi
# 859797      18.583       Perry County  Mississippi

# %%
#merge dgolfstr and 
# countydensdf
dgolfCounty1 = pd.merge(dgolfstr,countydensdf,how = 'inner',left_on='county state_x',right_on='name')
dgolfCounty1.head()
# Out:
#                               id_x                           name_x  \
# 0         adventist-discovery-park         Adventist DISCovery Park
# 1       agricultural-heritage-park       Agricultural Heritage Park
# 2                    halawaka-park                    Halawaka Park
# 3  smiths-station-disc-golf-course  Smiths Station Disc Golf Course
# 4     tumble-tree-disc-golf-course     Tumble Tree Disc Golf Course
#
#              city  state_x    zip  holeCount  rating   latitude  longitude  \
# 0         Opelika  Alabama  36804          3     NaN  32.645412 -85.378280
# 1          Auburn  Alabama  36830          9     NaN  32.594459 -85.492334
# 2           Salem  Alabama  36874         18     3.0  32.596803 -85.238553
# 3  Smiths Station  Alabama  36877         18     NaN  32.521926 -85.117811
# 4         Opelika  Alabama  36801         18     4.0  32.675108 -85.349505
#
#   Modified  ...       county state_x  county state_y            id_y  \
# 0       no  ...  Lee County, Alabama  Lee County, AL  0500000US01081
# 1       no  ...  Lee County, Alabama  Lee County, AL  0500000US01081
# 2       no  ...  Lee County, Alabama  Lee County, AL  0500000US01081
# 3       no  ...  Lee County, Alabama  Lee County, AL  0500000US01081
# 4       no  ...  Lee County, Alabama  Lee County, AL  0500000US01081
#
#                 name_y    type variable  year PopDensity      Area_1   Area_2
# 0  Lee County, Alabama  county  density  2018    262.185  Lee County  Alabama
# 1  Lee County, Alabama  county  density  2018    262.185  Lee County  Alabama
# 2  Lee County, Alabama  county  density  2018    262.185  Lee County  Alabama
# 3  Lee County, Alabama  county  density  2018    262.185  Lee County  Alabama
# 4  Lee County, Alabama  county  density  2018    262.185  Lee County  Alabama
#
# [5 rows x 32 columns]

# %%
# merge this df using county state_y
countyincomedf.head(2)
# Out:
#      FIPS_Code State           Area_name                     Attribute  \
# 270       1001    AL  Autauga County, AL  Median_Household_Income_2020
# 363       1003    AL  Baldwin County, AL  Median_Household_Income_2020
#
#      MedianHHIncome          Area_1 Area_2
# 270         67565.0  Autauga County     AL
# 363         71135.0  Baldwin County     AL

# %%
dgolfCounty2 = pd.merge(dgolfCounty1,countyincomedf,how = 'inner',left_on='county state_y',right_on='Area_name')
dgolfCounty2.head(2)
# Out:
#                          id_x                      name_x     city  state_x  \
# 0    adventist-discovery-park    Adventist DISCovery Park  Opelika  Alabama
# 1  agricultural-heritage-park  Agricultural Heritage Park   Auburn  Alabama
#
#      zip  holeCount  rating   latitude  longitude Modified  ... PopDensity  \
# 0  36804          3     NaN  32.645412 -85.378280       no  ...    262.185
# 1  36830          9     NaN  32.594459 -85.492334       no  ...    262.185
#
#      Area_1_x  Area_2_x  FIPS_Code  State       Area_name  \
# 0  Lee County   Alabama       1081     AL  Lee County, AL
# 1  Lee County   Alabama       1081     AL  Lee County, AL
#
#                       Attribute MedianHHIncome    Area_1_y  Area_2_y
# 0  Median_Household_Income_2020        58963.0  Lee County        AL
# 1  Median_Household_Income_2020        58963.0  Lee County        AL
#
# [2 rows x 39 columns]

# %%
dgolfCounty2.columns
# Out:
# Index(['id_x', 'name_x', 'city', 'state_x', 'zip', 'holeCount', 'rating',
#        'latitude', 'longitude', 'Modified', 'Comments', 'state_y', 'zipcode',
#        'total_pop', 'total_income', 'country', 'avg_income', 'cityURL',
#        'county', 'latstr', 'lonstr', 'county_clean', 'county state_x',
#        'county state_y', 'id_y', 'name_y', 'type', 'variable', 'year',
#        'PopDensity', 'Area_1_x', 'Area_2_x', 'FIPS_Code', 'State', 'Area_name',
#        'Attribute', 'MedianHHIncome', 'Area_1_y', 'Area_2_y'],
#       dtype='object')

# %%
dgolfcounty = dgolfCounty2[['id_x', 'name_x', 'city','county','Area_name', 'State','country', 'holeCount', 'rating','latitude', 'longitude', 'zipcode','PopDensity','total_pop', 'total_income', 'avg_income','MedianHHIncome']]
dgolfcounty = dgolfcounty.head(2)
# Out:
#                          id_x                      name_x     city  \
# 0    adventist-discovery-park    Adventist DISCovery Park  Opelika
# 1  agricultural-heritage-park  Agricultural Heritage Park   Auburn
#
#        county       Area_name State country  holeCount  rating   latitude  \
# 0  Lee County  Lee County, AL    AL     USA          3     NaN  32.645412
# 1  Lee County  Lee County, AL    AL     USA          9     NaN  32.594459
#
#    longitude  zipcode  PopDensity  total_pop  total_income   avg_income  \
# 0 -85.378280    36804     262.185       8240        417346  50648.78641
# 1 -85.492334    36830     262.185      16600       1485585  89493.07229
#
#    MedianHHIncome
# 0         58963.0
# 1         58963.0

# %%
dgolfcounty.to_csv('Resources/dgolfcounty.csv',index = False)

# %%
dgc = pd.read_csv('Resources/dgolfcounty.csv')
dgc.head()
# Out:
#                               id_x                           name_x  \
# 0         adventist-discovery-park         Adventist DISCovery Park
# 1       agricultural-heritage-park       Agricultural Heritage Park
# 2                    halawaka-park                    Halawaka Park
# 3  smiths-station-disc-golf-course  Smiths Station Disc Golf Course
# 4     tumble-tree-disc-golf-course     Tumble Tree Disc Golf Course
#
#              city      county       Area_name State country  holeCount  \
# 0         Opelika  Lee County  Lee County, AL    AL     USA          3
# 1          Auburn  Lee County  Lee County, AL    AL     USA          9
# 2           Salem  Lee County  Lee County, AL    AL     USA         18
# 3  Smiths Station  Lee County  Lee County, AL    AL     USA         18
# 4         Opelika  Lee County  Lee County, AL    AL     USA         18
#
#    rating   latitude  longitude  zipcode  PopDensity  total_pop  total_income  \
# 0     NaN  32.645412 -85.378280    36804     262.185       8240        417346
# 1     NaN  32.594459 -85.492334    36830     262.185      16600       1485585
# 2     3.0  32.596803 -85.238553    36874     262.185       3660        219136
# 3     NaN  32.521926 -85.117811    36877     262.185       5060        280151
# 4     4.0  32.675108 -85.349505    36801     262.185       9790        559225
#
#     avg_income  MedianHHIncome
# 0  50648.78641         58963.0
# 1  89493.07229         58963.0
# 2  59873.22404         58963.0
# 3  55365.81028         58963.0
# 4  57122.06333         58963.0

# %% [markdown]
# # create summary chart by county in P1_data_analysis_chris2.ipynb

# %% [markdown]
# FOR REFERENCE ONLY - code snippets and data pulls

# %%
#keep this commented out as a reference for what you can pull from geopy by latitude/longitude
#https://geopy.readthedocs.io/en/stable/#usage-with-pandas
# # trythis = location.raw
# trythis
# Out:
# {'place_id': 214458217,
#  'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. https://osm.org/copyright',
#  'osm_type': 'way',
#  'osm_id': 482881497,
#  'lat': '32.64581435',
#  'lon': '-85.37933547380712',
#  'display_name': 'Lee County Courthouse, South 9th Street, Opelika, Lee County, Alabama, 36801, United States',
#  'address': {'amenity': 'Lee County Courthouse',
#   'road': 'South 9th Street',
#   'town': 'Opelika',
#   'county': 'Lee County',
#   'state': 'Alabama',
#   'ISO3166-2-lvl4': 'US-AL',
#   'postcode': '36801',
#   'country': 'United States',
#   'country_code': 'us'},
#  'boundingbox': ['32.645538', '32.646093', '-85.3797587', '-85.3790976']}

# %%
# keep this commented out - reference for how to write a string variable to a new dataframe column, then change it to a float, then round
# df['latreturn'] = latreturn
# df['lngreturn'] = lngreturn
# df['latreturn'] = df['latreturn'].astype(float)
# df['lngreturn'] = df['lngreturn'].astype(float)
# df['latreturn'] = df['latreturn'].round(6)
# df['lngreturn'] = df['lngreturn'].round(6)
# df
# Out:
#                  amenity              road     town      county    state  \
# 0  Lee County Courthouse  South 9th Street  Opelika  Lee County  Alabama
#
#   ISO3166-2-lvl4 postcode        country country_code  latreturn  lngreturn
# 0          US-AL    36801  United States           us  32.645814 -85.379335

# %%
# Create DraftMerge - inner join DiscGolfcleandf and zipcodedf
#nice reference https://www.shanelynn.ie/merge-join-dataframes-python-pandas-index-1/
# draft_dgolf_avincome = pd.merge(discgolfcleandf,zipcodedf,how = 'inner',left_on='zip',right_on='zipcode')
# draft_dgolf_avincome.head()
